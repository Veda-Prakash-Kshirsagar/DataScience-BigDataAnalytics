# %%
#Veda Kshirsagar
#TE_A_61
#DSBDA_1_1

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Uber Request Data.csv")

# %%
df
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# 3         12/7/2016 21:08      12/7/2016 22:03
# ...

# %%
df.head(5)
# Out:
#    Request id Pickup point  Driver id          Status    Request timestamp  \
# 0         619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1         867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 2        1807         City        1.0  Trip Completed       12/7/2016 9:17
# 3        2532      Airport        1.0  Trip Completed      12/7/2016 21:08
# 4        3112         City        1.0  Trip Completed  13-07-2016 08:33:16
#
#         Drop timestamp
# 0      11/7/2016 13:00
# 1      11/7/2016 18:47
# 2       12/7/2016 9:58
# 3      12/7/2016 22:03
# 4  13-07-2016 09:25:47

# %%
df.tail(5)
# Out:
#       Request id Pickup point  Driver id             Status  \
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp Drop timestamp
# 6740  15-07-2016 23:49:03            NaN
# 6741  15-07-2016 23:50:05            NaN
# 6742  15-07-2016 23:52:06            NaN
# 6743  15-07-2016 23:54:39            NaN
# 6744  15-07-2016 23:55:03            NaN

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6745, step=1)

# %%
df.columns
# Out:
# Index(['Request id', 'Pickup point', 'Driver id', 'Status',
#        'Request timestamp', 'Drop timestamp'],
#       dtype='object')

# %%
df.shape
# Out:
# (6745, 6)

# %%
df.dtypes
# Out:
# Request id             int64
# Pickup point          object
# Driver id            float64
# Status                object
# Request timestamp     object
# Drop timestamp        object
# dtype: object

# %%
df.columns.values
# Out:
# array(['Request id', 'Pickup point', 'Driver id', 'Status',
#        'Request timestamp', 'Drop timestamp'], dtype=object)

# %%
df.describe(include='all')
# Out:
#          Request id Pickup point    Driver id          Status  \
# count   6745.000000         6745  4095.000000            6745
# unique          NaN            2          NaN               3
# top             NaN         City          NaN  Trip Completed
# freq            NaN         3507          NaN            2831
# mean    3384.644922          NaN   149.501343             NaN
# std     1955.099667          NaN    86.051994             NaN
# min        1.000000          NaN     1.000000             NaN
# 25%     1691.000000          NaN    75.000000             NaN
# 50%     3387.000000          NaN   149.000000             NaN
# 75%     5080.000000          NaN   224.000000             NaN
# max     6766.000000          NaN   300.000000             NaN
#
#        Request timestamp   Drop timestamp
# count               6745             2831
# unique              5618             2598
# top      11/7/2016 19:02  11/7/2016 13:00
# freq                   6                4
# ...

# %%
df['Status']
# Out:
# 0          Trip Completed
# 1          Trip Completed
# 2          Trip Completed
# 3          Trip Completed
# 4          Trip Completed
#               ...
# 6740    No Cars Available
# 6741    No Cars Available
# 6742    No Cars Available
# 6743    No Cars Available
# 6744    No Cars Available
# Name: Status, Length: 6745, dtype: object

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#                  Status    Request timestamp  Request id Pickup point  \
# 0        Trip Completed      11/7/2016 11:51         619      Airport
# 1        Trip Completed      11/7/2016 17:57         867      Airport
# 2        Trip Completed       12/7/2016 9:17        1807         City
# 3        Trip Completed      12/7/2016 21:08        2532      Airport
# 4        Trip Completed  13-07-2016 08:33:16        3112         City
# ...                 ...                  ...         ...          ...
# 6740  No Cars Available  15-07-2016 23:49:03        6745         City
# 6741  No Cars Available  15-07-2016 23:50:05        6752      Airport
# 6742  No Cars Available  15-07-2016 23:52:06        6751         City
# 6743  No Cars Available  15-07-2016 23:54:39        6754         City
# 6744  No Cars Available  15-07-2016 23:55:03        6753      Airport
#
#            Drop timestamp  Driver id
# 0         11/7/2016 13:00        1.0
# 1         11/7/2016 18:47        1.0
# ...

# %%
df.sort_values('Request id')
# Out:
#       Request id Pickup point  Driver id             Status  \
# 2700           1      Airport      285.0     Trip Completed
# 4098           2      Airport        NaN  No Cars Available
# 776            3      Airport       80.0     Trip Completed
# 4101           4         City        NaN  No Cars Available
# 2506           5      Airport      264.0     Trip Completed
# ...          ...          ...        ...                ...
# 2534        6762      Airport      267.0     Trip Completed
# 2137        6763         City      224.0     Trip Completed
# 2324        6764         City      243.0     Trip Completed
# 6165        6765      Airport        NaN  No Cars Available
# 1042        6766         City      108.0     Trip Completed
#
#         Request timestamp       Drop timestamp
# 2700       11/7/2016 0:20       11/7/2016 0:51
# 4098       11/7/2016 0:23                  NaN
# 776        11/7/2016 0:24       11/7/2016 1:31
# 4101       11/7/2016 0:37                  NaN
# ...

# %%
df.iloc[5]
# Out:
# Request id                          3879
# Pickup point                     Airport
# Driver id                            1.0
# Status                    Trip Completed
# Request timestamp    13-07-2016 21:57:28
# Drop timestamp       13-07-2016 22:28:59
# Name: 5, dtype: object

# %%
df.loc[:,['Request id','Status']]
# Out:
#       Request id             Status
# 0            619     Trip Completed
# 1            867     Trip Completed
# 2           1807     Trip Completed
# 3           2532     Trip Completed
# 4           3112     Trip Completed
# ...          ...                ...
# 6740        6745  No Cars Available
# 6741        6752  No Cars Available
# 6742        6751  No Cars Available
# 6743        6754  No Cars Available
# 6744        6753  No Cars Available
#
# [6745 rows x 2 columns]

# %%
df.iloc[:5,:]
# Out:
#    Request id Pickup point  Driver id          Status    Request timestamp  \
# 0         619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1         867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 2        1807         City        1.0  Trip Completed       12/7/2016 9:17
# 3        2532      Airport        1.0  Trip Completed      12/7/2016 21:08
# 4        3112         City        1.0  Trip Completed  13-07-2016 08:33:16
#
#         Drop timestamp
# 0      11/7/2016 13:00
# 1      11/7/2016 18:47
# 2       12/7/2016 9:58
# 3      12/7/2016 22:03
# 4  13-07-2016 09:25:47

# %%
df.iloc[:,:3]
# Out:
#       Request id Pickup point  Driver id
# 0            619      Airport        1.0
# 1            867      Airport        1.0
# 2           1807         City        1.0
# 3           2532      Airport        1.0
# 4           3112         City        1.0
# ...          ...          ...        ...
# 6740        6745         City        NaN
# 6741        6752      Airport        NaN
# 6742        6751         City        NaN
# 6743        6754         City        NaN
# 6744        6753      Airport        NaN
#
# [6745 rows x 3 columns]

# %%
df.iloc[:2,:2]
# Out:
#    Request id Pickup point
# 0         619      Airport
# 1         867      Airport
