# %%
#Veda Kshirsagar
#TE_A_61
#DSBDA_8

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = sns.load_dataset('titanic')

# %%
dataset
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
dataset.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
dataset["age"].fillna(dataset["age"].mean(),inplace=True)

# %%
dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dataset.shape
# Out:
# (891, 15)

# %%
#Distribution plot
sns.distplot(x = dataset['age'], bins = 10)
# Out:
# <ipython-input-9-fc86e5417ff6>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = dataset['age'], bins = 10)
# <Axes: ylabel='Density'>

# %%
sns.distplot(x = dataset['age'], bins = 10, kde = False)
# Out:
# <ipython-input-10-9f91a731dcac>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = dataset['age'], bins = 10, kde = False)
# <Axes: >

# %%
# Joint Plot
#type scatter
sns.jointplot(x = dataset['age'], y = dataset['fare'], kind ='scatter')

# %%
# Joint Plot
#type hexagonal plot
sns.jointplot(x = dataset['age'], y = dataset['fare'], kind ='hex')

# %%
#Rug plot
sns.rugplot(dataset['fare'])
# Out:
# <Axes: xlabel='fare'>

# %%
sns.rugplot(dataset['age'])
# Out:
# <Axes: xlabel='age'>

# %%
#Ctegorical Plot
#Bar plot
sns.barplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
#Bar plot
sns.barplot(x='sex', y='age', data=dataset, estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
#Count plot
sns.countplot(x='sex', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#Box plot
sns.boxplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
#Violin plot
sns.violinplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
#Violin plot
sns.violinplot(x='sex', y='age', data=dataset, hue = 'survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
#Strip Plot
sns.stripplot(x='sex', y='age', data=dataset, jitter=True)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x='sex', y='age', data=dataset, jitter=True, hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x='sex', y='age', data=dataset, jitter=False)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
#Swarm plot
sns.swarmplot(x='sex', y='age', data=dataset)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 18.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='sex', ylabel='age'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 24.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.swarmplot(x='sex', y='age', data=dataset, hue='survived')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 18.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='sex', ylabel='age'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 24.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
dataset.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-c187c74d1e71> in <cell line: 1>()
# ----> 1 dataset.corr()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
#    1840             result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
#Above error occurs because corr() works on numerical values only.
#Therefor applying label encoding to convert categorical data into numerical data

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
dataset['sex'] = label_encoder.fit_transform(dataset['sex'])
dataset['sex'].unique()
# Out:
# array([1, 0])

# %%
#for embarked
dataset['embarked'] = label_encoder.fit_transform(dataset['sex'])
dataset['embarked'].unique()
#for class
dataset['class'] = label_encoder.fit_transform(dataset['class'])
dataset['class'].unique()
#for who
dataset['who'] = label_encoder.fit_transform(dataset['who'])
dataset['who'].unique()
#foe adult_male
dataset['adult_male'] = label_encoder.fit_transform(dataset['adult_male'])
dataset['adult_male'].unique()
#for deck
dataset['deck'] = label_encoder.fit_transform(dataset['deck'])
dataset['deck'].unique()
#for embark_town
dataset['embark_town'] = label_encoder.fit_transform(dataset['embark_town'])
dataset['embark_town'].unique()
#for alive
dataset['alive'] = label_encoder.fit_transform(dataset['alive'])
dataset['alive'].unique()
#for alone
dataset['alone'] = label_encoder.fit_transform(dataset['alone'])
dataset['alone'].unique()
# Out:
# array([0, 1])

# %%
dataset.corr()
# Out:
#              survived    pclass       sex       age     sibsp     parch  \
# survived     1.000000 -0.338481 -0.543351 -0.069809 -0.035322  0.081629
# pclass      -0.338481  1.000000  0.131900 -0.331339  0.083081  0.018443
# sex         -0.543351  0.131900  1.000000  0.084153 -0.114631 -0.245489
# age         -0.069809 -0.331339  0.084153  1.000000 -0.232625 -0.179191
# sibsp       -0.035322  0.083081 -0.114631 -0.232625  1.000000  0.414838
# parch        0.081629  0.018443 -0.245489 -0.179191  0.414838  1.000000
# fare         0.257307 -0.549500 -0.182333  0.091566  0.159651  0.216225
# embarked    -0.543351  0.131900  1.000000  0.084153 -0.114631 -0.245489
# class       -0.338481  1.000000  0.131900 -0.331339  0.083081  0.018443
# who          0.325753 -0.196793 -0.639773  0.354507 -0.136003 -0.055682
# adult_male  -0.557080  0.094035  0.908578  0.253236 -0.253586 -0.349943
# deck        -0.294804  0.743251  0.118282 -0.249842  0.041333 -0.031308
# ...

# %%
corr = dataset.corr()
#Heat map
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
# 2)Histogram of price distribution for each passenger

sns.histplot(dataset['fare'], kde=False, bins=10)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
#
